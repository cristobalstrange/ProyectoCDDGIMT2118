# %%
import zipfile 
import os 
import fiona 
import pandas as pd 
import geopandas as gpd 
from bs4 import BeautifulSoup 

fiona.drvsupport.supported_drivers['libkml'] = 'rw' 
fiona.drvsupport.supported_drivers['LIBKML'] = 'rw'

# %%
import shutil 
import os

def save_kmz(kmz_file_path, folder_name):
    if os.path.isdir(folder_name):
        shutil.rmtree(folder_name)
    os.mkdir(folder_name) 
    with zipfile.ZipFile(kmz_file_path, "r") as kmz:
        kmz.extractall(folder_name)

save_kmz("ACS X REGION.kmz", '1')
save_kmz("ACS XI REGION.kmz", '2')
save_kmz("1 BARRIOS PROXMTE EN DESCANSO.kmz", '3')
save_kmz("2 EDUARDO ALMONACID.kmz", '4')
save_kmz("3 INGRID SALINAS.kmz", '5')
save_kmz("4 JAVIER DIAZ.kmz", '6')

# %%
def read_data(file_path, mode):
    gdf_list = []
    for layer in fiona.listlayers(file_path) :    
        gdf = gpd.read_file(file_path, driver='LIBKML', layer=layer)
        gdf_list.append(gdf)
    if mode == '1':
        return gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True))[['Name', 'geometry']].to_crs(4326)
    else:
        return gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True))[:24][['Name', 'geometry']].to_crs(4326)
    

gdf_zone = []
gdf_center = []
gdf_all = []
gdf_zone.append(read_data('1/doc.kml', '1'))
gdf_zone.append(read_data('2/doc.kml', '1'))
gdf_zone.append(read_data('3/doc.kml', '1'))
gdf_descanso = (read_data('3/doc.kml', '2'))
gdf_center.append(read_data('4/doc.kml', '2'))
gdf_center.append(read_data('5/doc.kml', '2'))
gdf_center.append(read_data('6/doc.kml', '2'))

gdf_all.append(read_data('1/doc.kml', '1'))
gdf_all.append(read_data('2/doc.kml', '1'))
gdf_all.append(read_data('3/doc.kml', '1'))
gdf_all.append(read_data('3/doc.kml', '2'))
gdf_all.append(read_data('4/doc.kml', '2'))
gdf_all.append(read_data('5/doc.kml', '2'))
gdf_all.append(read_data('6/doc.kml', '2'))

gdf_zone = pd.concat(gdf_zone)
gdf_center = pd.concat(gdf_center)
gdf_all = pd.concat(gdf_all)


gdf_all.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gdf_center.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gdf_center
# Out:
#                                  Name                               geometry
# 0            BARQUILLO (MEF03-101296)  POINT Z (-72.97009 -41.56678 0.00000)
# 1              BOLADOS (MEF04-110454)  POINT Z (-74.18728 -44.34708 0.00000)
# 2             CONCOTO (EA48 - 110466)  POINT Z (-73.80610 -44.16267 0.00000)
# 3   CANAL PEREZ NORTE (EA41 - 110523)  POINT Z (-73.84893 -44.14898 0.00000)
# 4               ELENA (EA40 - 110510)  POINT Z (-73.81244 -44.25456 0.00000)
# 5         GUAITECAS 2 (EA45 - 110704)  POINT Z (-73.87449 -43.92118 0.00000)
# 6                HUYAR (MEF10-101370)  POINT Z (-73.54890 -42.38871 0.00000)
# 7          ISLA PELADA (MEF11-100991)  POINT Z (-72.49835 -42.06297 0.00000)
# 8        ISLA SANCHEZ (EA20 - 110824)  POINT Z (-73.57099 -44.12652 0.00000)
# 9                JORGE (MEF01-110813)  POINT Z (-74.02981 -44.77855 0.00000)
# 10           MARGARITA (MEF02-110550)  POINT Z (-74.24368 -44.20240 0.00000)
# ...

# %%
fp_eq1 = "1/doc.kml"
fp_eq2 = "2/doc.kml"

gdf_list = []
for layer in fiona.listlayers(fp_eq1) :    
    gdf = gpd.read_file(fp_eq1, driver='LIBKML', layer=layer)
    gdf_list.append(gdf)
gdf1 = gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True))[['Name', 'geometry']].to_crs(4326)


gdf_list = []
for layer in fiona.listlayers(fp_eq2) :    
    gdf = gpd.read_file(fp_eq2, driver='LIBKML', layer=layer)
    gdf_list.append(gdf)
gdf2 = gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True))[['Name', 'geometry']].to_crs(4326)


gdf_list = []
for layer in fiona.listlayers(fp_eq2) :    
    gdf = gpd.read_file(fp_eq2, driver='LIBKML', layer=layer)
    gdf_list.append(gdf)
gdf3 = gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True))[:24][['Name', 'geometry']].to_crs(4326)


gdf = pd.concat([gdf1, gdf2])

gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in gdf['Name']:
    print(i)
# Out:
# 1
# 2
# 3a
# 3b
# 4
# 5
# 6
# 7
# 8
# 9a
# 9b
# 9c
# 10a
# 10b
# 11
# 12a
# 12b
# 12c
# 13
# 14
# 15
# 16
# 17a
# 17b
# 1
# 2
# 3a
# 3b
# 4
# 5
# 6
# 7
# 8
# 9a
# 9b
# 9c
# 10a
# 10b
# 11
# 12a
# 12b
# 12c
# 13
# 14
# 15
# 16
# 17b
# 17a
# 18a
# 18b
# 18c
# 18d
# 18e
# 19a
# 19c
# 19b
# 20
# 21a
# 21d
# 21c
# 21b
# 22a
# 22b
# 22c
# 22d
# 23a
# 23b
# 23c
# 24
# 25a
# 25b
# 26a
# 26b
# 27
# 28a
# 28b
# 28c
# 29
# 30b
# 30a
# 31a
# 32
# 31b
# 33
# 34
# 35
# 18a
# 18b
# 18c
# 18d
# 18e
# 19a
# 19c
# 19b
# 20
# 21a
# 21b
# 21c
# 21d
# 22a
# 22b
# 22c
# 22d
# 23a
# 23b
# 23c
# 24
# 25a
# 25b
# 26a
# 26b
# 27
# 28a
# 28b
# 28C
# 29
# 30a
# 30b
# 31a
# 32
# 31b
# 33
# 34
# 35

# %%
gdf_center.to_file('data_center.geojson', driver="GeoJSON")

# %%
import shapely 

def getAOI(geometry):
    minx, miny, maxx, maxy = geometry, geometry, geometry, geometry
    minx *= 1.0001
    miny *= 1.0001
    maxx *= 0.9999
    maxy *= 0.9999
    # df_polygon = [[coords[0], coords[1]] for coords in shapely.geometry.mapping(df['geometry'])['features'][0]['geometry']['coordinates'][0]]
    aoi_bbox = ee.Geometry.BBox(minx, miny, maxx, maxy)
    # aoi_poligon = ee.Geometry.Polygon(df_polygon)
    return aoi_bbox

def apply_scale_factors(image):
    # bbox, poligon = getAOI(osorno)
    
    image = image.clip(bbox)
    # image_poligon = image.clip(poligon)
    optical_bands = image.select('B.').multiply(2.75e-05).add(-0.2)
    return image.addBands(optical_bands, None, True)

def add_NDVI_NDBI(image):
    ndvi = image.normalizedDifference(['SR_B4', 'SR_B3']).rename('NDVI')
    ndbi = image.normalizedDifference(['SR_B7', 'SR_B4']).rename('NDBI')
    return image.addBands(ndvi, None, True)\
                .addBands(ndbi, None, True)

# %%
import json 

# aoi_bbox, aoi_poligon = getAOI(llaguepe['geometry'])
aoi = gpd.GeoSeries(llaguepe['geometry'].buffer(50)).to_crs(4326).to_json()
ee.Geometry.Polygon(json.loads(aoi)['features'][0]['geometry']['coordinates'], 4326)
# gpd.GeoSeries([llaguepe['geometry'].buffer(50)]).to_json()
# Out:
# C:\Users\jacmo\AppData\Local\Temp\ipykernel_14484\3502035260.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   aoi = gpd.GeoSeries(llaguepe['geometry'].buffer(50)).to_crs(4326).to_json()
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "GeometryConstructors.Polygon",
#     "arguments": {
#       "coordinates": {
#         "constantValue": [
#           [
#             [
#               -22.475958333333338,
#               -41.72168333333334
#             ],
#             [
#               -22.71672199972349,
#               -46.622540349811366
#             ],
#             [
#               -23.436694313171813,
#               -51.47619943413975
#             ],
#             [
#               -24.6289415467229,
#               -56.235917196056455
#             ],
#             [
#               -26.281981707769,
# ...

# %%
def getImage(aoi, dates, clouds=20, mosaic=False):
    collection = ee.ImageCollection('COPERNICUS/S2_SR').filterBounds(aoi).filterDate(dates[0], dates[1])
    collection = collection.filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', clouds))
    images = collection.aggregate_array('system:id').getInfo()
    return images

images = getImage(aoi, dates, clouds=40, mosaic=True) #352 imagenes

image = collection.first()
image = ee.Image(images[-1])
image = image.clip(aoi_bbox)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Input In [140], in <cell line: 7>()
# ...

# %%
import geemap

# aoi = gpd.GeoSeries(llaguepe['geometry'].buffer(0.006)).to_crs(4326).to_json()
# aoi_bbox = ee.Geometry.Polygon(json.loads(aoi)['features'][0]['geometry']['coordinates'], 'EPSG:4326')


Map = geemap.Map(center=[-41.72168, -72.47596], zoom=12.5)
Map.addLayer(aoi_bbox)


# ndwi = image.select(['SR_B3'])
# ndwiViz = {'palette': ['00FFFF', '0000FF']}
# Map.addLayer(ndwi, ndwiViz, 'NDWI', True)


imageRGB = image.visualize(**{'bands': ['B1', 'B2', 'B3'],'min':0, 'max': 10})
# ndwiRGB = ndwiMasked.visualize(**{
#   'min': 0.5,
#   'max': 1,
#   'palette': ['00FFFF', '0000FF']
# })

Map.addLayer(imageRGB, {}, 'imageRGB', True)


Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-41.72168, -72.47596], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Sear…

# %%
Map = geemap.Map(center=[-41.72168, -72.47596], zoom=4)
url = 'https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2019_Land_Cover_L48/wms?'
Map.add_wms_layer(
    url=url,
    layers='NLCD_2019_Land_Cover_L48',
    name='NLCD 2019',
    format='image/png',
    attribution='MRLC',
    transparent=True,
)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-41.72168, -72.47596], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Sear…
